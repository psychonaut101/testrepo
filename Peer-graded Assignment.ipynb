# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Ann Love</b>
# <br>Desired occupation: Data Scientist focused on virtual reality

# %% [markdown]
# <i> I am interested in Data Science because of its complexity.  There are many subject area where you can dive deep and learn.  When you get lost into something, you sort of go into this self discovery.  One of the things I really wanna get into is ANN, which stands for Artificial Neural Network. Pun intended. </i>

# %% [markdown]
# ### In cell 5, my code is suppose to show how true I am to myself.

# %%
def ann(true, self):
    return "Ann will follow her " + true + " and all of her dreams will come " + self + "." 
print(ann("dreams", "true"))
# Out:
# Ann will follow her dreams and all of her dreams will come true.

# %% [markdown]
# - love
# - love me
# - do
# 1. you
# 2. know
# 3. I love you
# ***
# so
# ***
# pleeeeeease
# ***
# Love me do 🎶
